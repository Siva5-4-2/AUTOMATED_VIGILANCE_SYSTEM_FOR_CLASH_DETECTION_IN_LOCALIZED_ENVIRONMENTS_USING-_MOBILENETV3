# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import platform
from IPython.display import clear_output
print(platform.platform())

def resolve_dir(Dir):
    if not os.path.exists(Dir):
        os.mkdir(Dir)

def reset_path(Dir):
    if not os.path.exists(Dir):
        os.mkdir(Dir)
    else:
        os.system('rm -f {}/*'.format( Dir))
# Out:
# Linux-5.10.147+-x86_64-with-glibc2.31

# %%
import tensorflow as tf
tf.random.set_seed(73)
TPU_INIT = False

if TPU_INIT:
    try:
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()
        tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)
    
    except ValueError:
        raise BaseException('ERROR: Not connected to a TPU runtime!')
else:
    # !nvidia-smi
;    
print("Tensorflow version " + tf.__version__)
# Out:
# Tue Mar 14 09:08:36 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   65C    P0    26W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Tensorflow version 2.11.0

# %%
MyDrive = '/content/drive/MyDrive'
PROJECT_DIR = '/content/drive/MyDrive/dataset/Real Life Violence Dataset'

# %% [markdown]
# ## **Preprocessing**
# + **Getting frames form video**
# + **some image argumentations**

# %%
import cv2
import os
import imageio
import imgaug.augmenters as iaa
import imgaug as ia

IMG_SIZE = 128
ColorChannels = 3

def video_to_frames(video):
    vidcap = cv2.VideoCapture(video)
    
    import math
    rate = math.floor(vidcap.get(3))
    count = 0
    
    ImageFrames = []
    while vidcap.isOpened():
        ID = vidcap.get(1)
        success, image = vidcap.read()
        
        if success:
            # skipping frames to avoid duplications 
            if (ID % 7 == 0):
                flip = iaa.Fliplr(1.0)
                zoom = iaa.Affine(scale=1.3)
                random_brightness = iaa.Multiply((1, 1.3))
                rotate = iaa.Affine(rotate=(-25, 25))
                
                image_aug = flip(image = image)
                image_aug = random_brightness(image = image_aug)
                image_aug = zoom(image = image_aug)
                image_aug = rotate(image = image_aug)
                
                rgb_img = cv2.cvtColor(image_aug, cv2.COLOR_BGR2RGB)
                resized = cv2.resize(rgb_img, (IMG_SIZE, IMG_SIZE))
                ImageFrames.append(resized)
                
            count += 1
        else:
            break
    
    vidcap.release()
    
    return ImageFrames

# %%
# %%time
from tqdm import tqdm

VideoDataDir = PROJECT_DIR 
print('we have \n{} Violence videos \n{} NonViolence videos'.format(
              len(os.listdir(VideoDataDir + '/Violence')), 
              len(os.listdir(VideoDataDir + '/NonViolence'))))

X_original = []
y_original = []

print('i choose 700 videos out of 2000, cuz of memory issue')
CLASSES = ["NonViolence", "Violence"]
#700 <- 350 + 350

for category in os.listdir(VideoDataDir):
    path = os.path.join(VideoDataDir, category)
    class_num = CLASSES.index(category)
    for i, video in enumerate(tqdm(os.listdir(path)[0:400])):
        frames = video_to_frames(path + '/' + video)
        for j, frame in enumerate(frames):
            X_original.append(frame)
            y_original.append(class_num)
# Out:
# we have
# 1000 Violence videos
# 1000 NonViolence videos
# i choose 700 videos out of 2000, cuz of memory issue
# 100%|██████████| 400/400 [02:51<00:00,  2.33it/s]
# 100%|██████████| 400/400 [05:14<00:00,  1.27it/s]
# CPU times: user 10min 22s, sys: 19 s, total: 10min 41s
# Wall time: 8min 6s

# %%
import numpy as np
X_original = np.array(X_original).reshape(-1 , IMG_SIZE * IMG_SIZE * 3)
y_original = np.array(y_original)
len(X_original)
# Out:
# 15427

# %%
from sklearn.model_selection import StratifiedShuffleSplit

stratified_sample = StratifiedShuffleSplit(n_splits=2, test_size=0.3, random_state=73)

for train_index, test_index in stratified_sample.split(X_original, y_original):
    X_train, X_test = X_original[train_index], X_original[test_index]
    y_train, y_test = y_original[train_index], y_original[test_index]

X_train_nn = X_train.reshape(-1, IMG_SIZE, IMG_SIZE, 3) / 255
X_test_nn = X_test.reshape(-1, IMG_SIZE, IMG_SIZE, 3) / 255

# %% [markdown]
# ## **Model Training**

# %%
# !pip install imutils
clear_output()

# %%
import cv2
import os
import numpy as np
import pickle
import matplotlib
matplotlib.use("Agg")

from keras.layers import Input
from keras.models import Model
from keras.layers.core import Dropout,Flatten,Dense

import matplotlib.pyplot as plt

# %%
epochs = 60

from keras import regularizers
kernel_regularizer = regularizers.l2(0.0001)

from keras.applications.mobilenet_v3 import MobileNetV3Large

def load_layers():
    input_tensor = Input(shape=(IMG_SIZE, IMG_SIZE, ColorChannels))
    baseModel = MobileNetV3Large(pooling='avg',
                                 include_top=False, 
                                 input_tensor=input_tensor)
    
    headModel = baseModel.output   
    headModel = Dense(1, activation="sigmoid")(headModel)
    model = Model(inputs=baseModel.input, outputs=headModel)

    for layer in baseModel.layers:
        layer.trainable = False

    print("Compiling model...")
    model.compile(loss="binary_crossentropy",
                    optimizer='adam',
                    metrics=["accuracy"])

    return model

if TPU_INIT:
    with tpu_strategy.scope():
        model = load_layers()
else:
    model = load_layers()

model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 [==============================] - 0s 0us/step
# Compiling model...
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 128, 128, 3)  0           ['input_1[0][0]']
#
#  Conv (Conv2D)                  (None, 64, 64, 16)   432         ['rescaling[0][0]']
#
#  Conv/BatchNorm (BatchNormaliza  (None, 64, 64, 16)  64          ['Conv[0][0]']
#  tion)
#
#  tf.__operators__.add (TFOpLamb  (None, 64, 64, 16)  0           ['Conv/BatchNorm[0][0]']
#  da)
#
#  re_lu (ReLU)                   (None, 64, 64, 16)   0           ['tf.__operators__.add[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 64, 64, 16)   0           ['re_lu[0][0]']
#
#  multiply (Multiply)            (None, 64, 64, 16)   0           ['Conv/BatchNorm[0][0]',
#                                                                   'tf.math.multiply[0][0]']
#
#  expanded_conv/depthwise (Depth  (None, 64, 64, 16)  144         ['multiply[0][0]']
#  wiseConv2D)
#
#  expanded_conv/depthwise/BatchN  (None, 64, 64, 16)  64          ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)
#
#  re_lu_1 (ReLU)                 (None, 64, 64, 16)   0           ['expanded_conv/depthwise/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv/project (Conv2D)  (None, 64, 64, 16)  256         ['re_lu_1[0][0]']
#
#  expanded_conv/project/BatchNor  (None, 64, 64, 16)  64          ['expanded_conv/project[0][0]']
#  m (BatchNormalization)
#
#  expanded_conv/Add (Add)        (None, 64, 64, 16)   0           ['multiply[0][0]',
#                                                                   'expanded_conv/project/BatchNorm
#                                                                  [0][0]']
#
#  expanded_conv_1/expand (Conv2D  (None, 64, 64, 64)  1024        ['expanded_conv/Add[0][0]']
#  )
#
#  expanded_conv_1/expand/BatchNo  (None, 64, 64, 64)  256         ['expanded_conv_1/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_2 (ReLU)                 (None, 64, 64, 64)   0           ['expanded_conv_1/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_1/depthwise/pad   (None, 65, 65, 64)  0           ['re_lu_2[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_1/depthwise (Dep  (None, 32, 32, 64)  576         ['expanded_conv_1/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_1/depthwise/Batc  (None, 32, 32, 64)  256         ['expanded_conv_1/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_3 (ReLU)                 (None, 32, 32, 64)   0           ['expanded_conv_1/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_1/project (Conv2  (None, 32, 32, 24)  1536        ['re_lu_3[0][0]']
#  D)
#
#  expanded_conv_1/project/BatchN  (None, 32, 32, 24)  96          ['expanded_conv_1/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/expand (Conv2D  (None, 32, 32, 72)  1728        ['expanded_conv_1/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_2/expand/BatchNo  (None, 32, 32, 72)  288         ['expanded_conv_2/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_4 (ReLU)                 (None, 32, 32, 72)   0           ['expanded_conv_2/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_2/depthwise (Dep  (None, 32, 32, 72)  648         ['re_lu_4[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_2/depthwise/Batc  (None, 32, 32, 72)  288         ['expanded_conv_2/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_5 (ReLU)                 (None, 32, 32, 72)   0           ['expanded_conv_2/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_2/project (Conv2  (None, 32, 32, 24)  1728        ['re_lu_5[0][0]']
#  D)
#
#  expanded_conv_2/project/BatchN  (None, 32, 32, 24)  96          ['expanded_conv_2/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_2/Add (Add)      (None, 32, 32, 24)   0           ['expanded_conv_1/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_2/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_3/expand (Conv2D  (None, 32, 32, 72)  1728        ['expanded_conv_2/Add[0][0]']
#  )
#
#  expanded_conv_3/expand/BatchNo  (None, 32, 32, 72)  288         ['expanded_conv_3/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_6 (ReLU)                 (None, 32, 32, 72)   0           ['expanded_conv_3/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_3/depthwise/pad   (None, 35, 35, 72)  0           ['re_lu_6[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_3/depthwise (Dep  (None, 16, 16, 72)  1800        ['expanded_conv_3/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_3/depthwise/Batc  (None, 16, 16, 72)  288         ['expanded_conv_3/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_7 (ReLU)                 (None, 16, 16, 72)   0           ['expanded_conv_3/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 72)    0           ['re_lu_7[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    1752        ['expanded_conv_3/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 24)    0           ['expanded_conv_3/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_3/squeeze_excite  (None, 1, 1, 72)    1800        ['expanded_conv_3/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 1, 1, 72)    0           ['expanded_conv_3/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_8 (ReLU)                 (None, 1, 1, 72)     0           ['tf.__operators__.add_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 1, 1, 72)    0           ['re_lu_8[0][0]']
#  )
#
#  expanded_conv_3/squeeze_excite  (None, 16, 16, 72)  0           ['re_lu_7[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_1[0][0]']
#
#  expanded_conv_3/project (Conv2  (None, 16, 16, 40)  2880        ['expanded_conv_3/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_3/project/BatchN  (None, 16, 16, 40)  160         ['expanded_conv_3/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/expand (Conv2D  (None, 16, 16, 120)  4800       ['expanded_conv_3/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_4/expand/BatchNo  (None, 16, 16, 120)  480        ['expanded_conv_4/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_9 (ReLU)                 (None, 16, 16, 120)  0           ['expanded_conv_4/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_4/depthwise (Dep  (None, 16, 16, 120)  3000       ['re_lu_9[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_4/depthwise/Batc  (None, 16, 16, 120)  480        ['expanded_conv_4/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_10 (ReLU)                (None, 16, 16, 120)  0           ['expanded_conv_4/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 120)   0           ['re_lu_10[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_4/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_4/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_4/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_4/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 1, 1, 120)   0           ['expanded_conv_4/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_11 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_2[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 1, 1, 120)   0           ['re_lu_11[0][0]']
#  )
#
#  expanded_conv_4/squeeze_excite  (None, 16, 16, 120)  0          ['re_lu_10[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_2[0][0]']
#
#  expanded_conv_4/project (Conv2  (None, 16, 16, 40)  4800        ['expanded_conv_4/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_4/project/BatchN  (None, 16, 16, 40)  160         ['expanded_conv_4/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_4/Add (Add)      (None, 16, 16, 40)   0           ['expanded_conv_3/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_4/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_5/expand (Conv2D  (None, 16, 16, 120)  4800       ['expanded_conv_4/Add[0][0]']
#  )
#
#  expanded_conv_5/expand/BatchNo  (None, 16, 16, 120)  480        ['expanded_conv_5/expand[0][0]']
#  rm (BatchNormalization)
#
#  re_lu_12 (ReLU)                (None, 16, 16, 120)  0           ['expanded_conv_5/expand/BatchNor
#                                                                  m[0][0]']
#
#  expanded_conv_5/depthwise (Dep  (None, 16, 16, 120)  3000       ['re_lu_12[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_5/depthwise/Batc  (None, 16, 16, 120)  480        ['expanded_conv_5/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  re_lu_13 (ReLU)                (None, 16, 16, 120)  0           ['expanded_conv_5/depthwise/Batch
#                                                                  Norm[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 120)   0           ['re_lu_13[0][0]']
#  /AvgPool (GlobalAveragePooling
#  2D)
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 32)    3872        ['expanded_conv_5/squeeze_excite/
#  /Conv (Conv2D)                                                  AvgPool[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 32)    0           ['expanded_conv_5/squeeze_excite/
#  /Relu (ReLU)                                                    Conv[0][0]']
#
#  expanded_conv_5/squeeze_excite  (None, 1, 1, 120)   3960        ['expanded_conv_5/squeeze_excite/
#  /Conv_1 (Conv2D)                                                Relu[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 1, 1, 120)   0           ['expanded_conv_5/squeeze_excite/
#  mbda)                                                           Conv_1[0][0]']
#
#  re_lu_14 (ReLU)                (None, 1, 1, 120)    0           ['tf.__operators__.add_3[0][0]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, 1, 1, 120)   0           ['re_lu_14[0][0]']
#  )
#
#  expanded_conv_5/squeeze_excite  (None, 16, 16, 120)  0          ['re_lu_13[0][0]',
#  /Mul (Multiply)                                                  'tf.math.multiply_3[0][0]']
#
#  expanded_conv_5/project (Conv2  (None, 16, 16, 40)  4800        ['expanded_conv_5/squeeze_excite/
#  D)                                                              Mul[0][0]']
#
#  expanded_conv_5/project/BatchN  (None, 16, 16, 40)  160         ['expanded_conv_5/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_5/Add (Add)      (None, 16, 16, 40)   0           ['expanded_conv_4/Add[0][0]',
#                                                                   'expanded_conv_5/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_6/expand (Conv2D  (None, 16, 16, 240)  9600       ['expanded_conv_5/Add[0][0]']
#  )
#
#  expanded_conv_6/expand/BatchNo  (None, 16, 16, 240)  960        ['expanded_conv_6/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_4 (TFOpLa  (None, 16, 16, 240)  0          ['expanded_conv_6/expand/BatchNor
#  mbda)                                                           m[0][0]']
#
#  re_lu_15 (ReLU)                (None, 16, 16, 240)  0           ['tf.__operators__.add_4[0][0]']
#
#  tf.math.multiply_4 (TFOpLambda  (None, 16, 16, 240)  0          ['re_lu_15[0][0]']
#  )
#
#  multiply_1 (Multiply)          (None, 16, 16, 240)  0           ['expanded_conv_6/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_4[0][0]']
#
#  expanded_conv_6/depthwise/pad   (None, 17, 17, 240)  0          ['multiply_1[0][0]']
#  (ZeroPadding2D)
#
#  expanded_conv_6/depthwise (Dep  (None, 8, 8, 240)   2160        ['expanded_conv_6/depthwise/pad[0
#  thwiseConv2D)                                                   ][0]']
#
#  expanded_conv_6/depthwise/Batc  (None, 8, 8, 240)   960         ['expanded_conv_6/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 8, 8, 240)   0           ['expanded_conv_6/depthwise/Batch
#  mbda)                                                           Norm[0][0]']
#
#  re_lu_16 (ReLU)                (None, 8, 8, 240)    0           ['tf.__operators__.add_5[0][0]']
#
#  tf.math.multiply_5 (TFOpLambda  (None, 8, 8, 240)   0           ['re_lu_16[0][0]']
#  )
#
#  multiply_2 (Multiply)          (None, 8, 8, 240)    0           ['expanded_conv_6/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_5[0][0]']
#
#  expanded_conv_6/project (Conv2  (None, 8, 8, 80)    19200       ['multiply_2[0][0]']
#  D)
#
#  expanded_conv_6/project/BatchN  (None, 8, 8, 80)    320         ['expanded_conv_6/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/expand (Conv2D  (None, 8, 8, 200)   16000       ['expanded_conv_6/project/BatchNo
#  )                                                               rm[0][0]']
#
#  expanded_conv_7/expand/BatchNo  (None, 8, 8, 200)   800         ['expanded_conv_7/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_6 (TFOpLa  (None, 8, 8, 200)   0           ['expanded_conv_7/expand/BatchNor
#  mbda)                                                           m[0][0]']
#
#  re_lu_17 (ReLU)                (None, 8, 8, 200)    0           ['tf.__operators__.add_6[0][0]']
#
#  tf.math.multiply_6 (TFOpLambda  (None, 8, 8, 200)   0           ['re_lu_17[0][0]']
#  )
#
#  multiply_3 (Multiply)          (None, 8, 8, 200)    0           ['expanded_conv_7/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_6[0][0]']
#
#  expanded_conv_7/depthwise (Dep  (None, 8, 8, 200)   1800        ['multiply_3[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_7/depthwise/Batc  (None, 8, 8, 200)   800         ['expanded_conv_7/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 8, 8, 200)   0           ['expanded_conv_7/depthwise/Batch
#  mbda)                                                           Norm[0][0]']
#
#  re_lu_18 (ReLU)                (None, 8, 8, 200)    0           ['tf.__operators__.add_7[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, 8, 8, 200)   0           ['re_lu_18[0][0]']
#  )
#
#  multiply_4 (Multiply)          (None, 8, 8, 200)    0           ['expanded_conv_7/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_7[0][0]']
#
#  expanded_conv_7/project (Conv2  (None, 8, 8, 80)    16000       ['multiply_4[0][0]']
#  D)
#
#  expanded_conv_7/project/BatchN  (None, 8, 8, 80)    320         ['expanded_conv_7/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_7/Add (Add)      (None, 8, 8, 80)     0           ['expanded_conv_6/project/BatchNo
#                                                                  rm[0][0]',
#                                                                   'expanded_conv_7/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_8/expand (Conv2D  (None, 8, 8, 184)   14720       ['expanded_conv_7/Add[0][0]']
#  )
#
#  expanded_conv_8/expand/BatchNo  (None, 8, 8, 184)   736         ['expanded_conv_8/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_8 (TFOpLa  (None, 8, 8, 184)   0           ['expanded_conv_8/expand/BatchNor
#  mbda)                                                           m[0][0]']
#
#  re_lu_19 (ReLU)                (None, 8, 8, 184)    0           ['tf.__operators__.add_8[0][0]']
#
#  tf.math.multiply_8 (TFOpLambda  (None, 8, 8, 184)   0           ['re_lu_19[0][0]']
#  )
#
#  multiply_5 (Multiply)          (None, 8, 8, 184)    0           ['expanded_conv_8/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_8[0][0]']
#
#  expanded_conv_8/depthwise (Dep  (None, 8, 8, 184)   1656        ['multiply_5[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_8/depthwise/Batc  (None, 8, 8, 184)   736         ['expanded_conv_8/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 8, 8, 184)   0           ['expanded_conv_8/depthwise/Batch
#  mbda)                                                           Norm[0][0]']
#
#  re_lu_20 (ReLU)                (None, 8, 8, 184)    0           ['tf.__operators__.add_9[0][0]']
#
#  tf.math.multiply_9 (TFOpLambda  (None, 8, 8, 184)   0           ['re_lu_20[0][0]']
#  )
#
#  multiply_6 (Multiply)          (None, 8, 8, 184)    0           ['expanded_conv_8/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_9[0][0]']
#
#  expanded_conv_8/project (Conv2  (None, 8, 8, 80)    14720       ['multiply_6[0][0]']
#  D)
#
#  expanded_conv_8/project/BatchN  (None, 8, 8, 80)    320         ['expanded_conv_8/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_8/Add (Add)      (None, 8, 8, 80)     0           ['expanded_conv_7/Add[0][0]',
#                                                                   'expanded_conv_8/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_9/expand (Conv2D  (None, 8, 8, 184)   14720       ['expanded_conv_8/Add[0][0]']
#  )
#
#  expanded_conv_9/expand/BatchNo  (None, 8, 8, 184)   736         ['expanded_conv_9/expand[0][0]']
#  rm (BatchNormalization)
#
#  tf.__operators__.add_10 (TFOpL  (None, 8, 8, 184)   0           ['expanded_conv_9/expand/BatchNor
#  ambda)                                                          m[0][0]']
#
#  re_lu_21 (ReLU)                (None, 8, 8, 184)    0           ['tf.__operators__.add_10[0][0]']
#
#  tf.math.multiply_10 (TFOpLambd  (None, 8, 8, 184)   0           ['re_lu_21[0][0]']
#  a)
#
#  multiply_7 (Multiply)          (None, 8, 8, 184)    0           ['expanded_conv_9/expand/BatchNor
#                                                                  m[0][0]',
#                                                                   'tf.math.multiply_10[0][0]']
#
#  expanded_conv_9/depthwise (Dep  (None, 8, 8, 184)   1656        ['multiply_7[0][0]']
#  thwiseConv2D)
#
#  expanded_conv_9/depthwise/Batc  (None, 8, 8, 184)   736         ['expanded_conv_9/depthwise[0][0]
#  hNorm (BatchNormalization)                                      ']
#
#  tf.__operators__.add_11 (TFOpL  (None, 8, 8, 184)   0           ['expanded_conv_9/depthwise/Batch
#  ambda)                                                          Norm[0][0]']
#
#  re_lu_22 (ReLU)                (None, 8, 8, 184)    0           ['tf.__operators__.add_11[0][0]']
#
#  tf.math.multiply_11 (TFOpLambd  (None, 8, 8, 184)   0           ['re_lu_22[0][0]']
#  a)
#
#  multiply_8 (Multiply)          (None, 8, 8, 184)    0           ['expanded_conv_9/depthwise/Batch
#                                                                  Norm[0][0]',
#                                                                   'tf.math.multiply_11[0][0]']
#
#  expanded_conv_9/project (Conv2  (None, 8, 8, 80)    14720       ['multiply_8[0][0]']
#  D)
#
#  expanded_conv_9/project/BatchN  (None, 8, 8, 80)    320         ['expanded_conv_9/project[0][0]']
#  orm (BatchNormalization)
#
#  expanded_conv_9/Add (Add)      (None, 8, 8, 80)     0           ['expanded_conv_8/Add[0][0]',
#                                                                   'expanded_conv_9/project/BatchNo
#                                                                  rm[0][0]']
#
#  expanded_conv_10/expand (Conv2  (None, 8, 8, 480)   38400       ['expanded_conv_9/Add[0][0]']
#  D)
#
#  expanded_conv_10/expand/BatchN  (None, 8, 8, 480)   1920        ['expanded_conv_10/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_12 (TFOpL  (None, 8, 8, 480)   0           ['expanded_conv_10/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_23 (ReLU)                (None, 8, 8, 480)    0           ['tf.__operators__.add_12[0][0]']
#
#  tf.math.multiply_12 (TFOpLambd  (None, 8, 8, 480)   0           ['re_lu_23[0][0]']
#  a)
#
#  multiply_9 (Multiply)          (None, 8, 8, 480)    0           ['expanded_conv_10/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_12[0][0]']
#
#  expanded_conv_10/depthwise (De  (None, 8, 8, 480)   4320        ['multiply_9[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_10/depthwise/Bat  (None, 8, 8, 480)   1920        ['expanded_conv_10/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_13 (TFOpL  (None, 8, 8, 480)   0           ['expanded_conv_10/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_24 (ReLU)                (None, 8, 8, 480)    0           ['tf.__operators__.add_13[0][0]']
#
#  tf.math.multiply_13 (TFOpLambd  (None, 8, 8, 480)   0           ['re_lu_24[0][0]']
#  a)
#
#  multiply_10 (Multiply)         (None, 8, 8, 480)    0           ['expanded_conv_10/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_13[0][0]']
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 480)   0           ['multiply_10[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_10/squeeze_excit  (None, 1, 1, 120)   57720       ['expanded_conv_10/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
# ...
#  orm (BatchNormalization)
#
#  tf.__operators__.add_21 (TFOpL  (None, 4, 4, 960)   0           ['expanded_conv_13/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_32 (ReLU)                (None, 4, 4, 960)    0           ['tf.__operators__.add_21[0][0]']
#
#  tf.math.multiply_21 (TFOpLambd  (None, 4, 4, 960)   0           ['re_lu_32[0][0]']
#  a)
#
#  multiply_15 (Multiply)         (None, 4, 4, 960)    0           ['expanded_conv_13/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_21[0][0]']
#
#  expanded_conv_13/depthwise (De  (None, 4, 4, 960)   24000       ['multiply_15[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_13/depthwise/Bat  (None, 4, 4, 960)   3840        ['expanded_conv_13/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_22 (TFOpL  (None, 4, 4, 960)   0           ['expanded_conv_13/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_33 (ReLU)                (None, 4, 4, 960)    0           ['tf.__operators__.add_22[0][0]']
#
#  tf.math.multiply_22 (TFOpLambd  (None, 4, 4, 960)   0           ['re_lu_33[0][0]']
#  a)
#
#  multiply_16 (Multiply)         (None, 4, 4, 960)    0           ['expanded_conv_13/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_22[0][0]']
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 960)   0           ['multiply_16[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 240)   230640      ['expanded_conv_13/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 240)   0           ['expanded_conv_13/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_13/squeeze_excit  (None, 1, 1, 960)   231360      ['expanded_conv_13/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_23 (TFOpL  (None, 1, 1, 960)   0           ['expanded_conv_13/squeeze_excite
#  ambda)                                                          /Conv_1[0][0]']
#
#  re_lu_34 (ReLU)                (None, 1, 1, 960)    0           ['tf.__operators__.add_23[0][0]']
#
#  tf.math.multiply_23 (TFOpLambd  (None, 1, 1, 960)   0           ['re_lu_34[0][0]']
#  a)
#
#  expanded_conv_13/squeeze_excit  (None, 4, 4, 960)   0           ['multiply_16[0][0]',
#  e/Mul (Multiply)                                                 'tf.math.multiply_23[0][0]']
#
#  expanded_conv_13/project (Conv  (None, 4, 4, 160)   153600      ['expanded_conv_13/squeeze_excite
#  2D)                                                             /Mul[0][0]']
#
#  expanded_conv_13/project/Batch  (None, 4, 4, 160)   640         ['expanded_conv_13/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_13/Add (Add)     (None, 4, 4, 160)    0           ['expanded_conv_12/project/BatchN
#                                                                  orm[0][0]',
#                                                                   'expanded_conv_13/project/BatchN
#                                                                  orm[0][0]']
#
#  expanded_conv_14/expand (Conv2  (None, 4, 4, 960)   153600      ['expanded_conv_13/Add[0][0]']
#  D)
#
#  expanded_conv_14/expand/BatchN  (None, 4, 4, 960)   3840        ['expanded_conv_14/expand[0][0]']
#  orm (BatchNormalization)
#
#  tf.__operators__.add_24 (TFOpL  (None, 4, 4, 960)   0           ['expanded_conv_14/expand/BatchNo
#  ambda)                                                          rm[0][0]']
#
#  re_lu_35 (ReLU)                (None, 4, 4, 960)    0           ['tf.__operators__.add_24[0][0]']
#
#  tf.math.multiply_24 (TFOpLambd  (None, 4, 4, 960)   0           ['re_lu_35[0][0]']
#  a)
#
#  multiply_17 (Multiply)         (None, 4, 4, 960)    0           ['expanded_conv_14/expand/BatchNo
#                                                                  rm[0][0]',
#                                                                   'tf.math.multiply_24[0][0]']
#
#  expanded_conv_14/depthwise (De  (None, 4, 4, 960)   24000       ['multiply_17[0][0]']
#  pthwiseConv2D)
#
#  expanded_conv_14/depthwise/Bat  (None, 4, 4, 960)   3840        ['expanded_conv_14/depthwise[0][0
#  chNorm (BatchNormalization)                                     ]']
#
#  tf.__operators__.add_25 (TFOpL  (None, 4, 4, 960)   0           ['expanded_conv_14/depthwise/Batc
#  ambda)                                                          hNorm[0][0]']
#
#  re_lu_36 (ReLU)                (None, 4, 4, 960)    0           ['tf.__operators__.add_25[0][0]']
#
#  tf.math.multiply_25 (TFOpLambd  (None, 4, 4, 960)   0           ['re_lu_36[0][0]']
#  a)
#
#  multiply_18 (Multiply)         (None, 4, 4, 960)    0           ['expanded_conv_14/depthwise/Batc
#                                                                  hNorm[0][0]',
#                                                                   'tf.math.multiply_25[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 960)   0           ['multiply_18[0][0]']
#  e/AvgPool (GlobalAveragePoolin
#  g2D)
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 240)   230640      ['expanded_conv_14/squeeze_excite
#  e/Conv (Conv2D)                                                 /AvgPool[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 240)   0           ['expanded_conv_14/squeeze_excite
#  e/Relu (ReLU)                                                   /Conv[0][0]']
#
#  expanded_conv_14/squeeze_excit  (None, 1, 1, 960)   231360      ['expanded_conv_14/squeeze_excite
#  e/Conv_1 (Conv2D)                                               /Relu[0][0]']
#
#  tf.__operators__.add_26 (TFOpL  (None, 1, 1, 960)   0           ['expanded_conv_14/squeeze_excite
#  ambda)                                                          /Conv_1[0][0]']
#
#  re_lu_37 (ReLU)                (None, 1, 1, 960)    0           ['tf.__operators__.add_26[0][0]']
#
#  tf.math.multiply_26 (TFOpLambd  (None, 1, 1, 960)   0           ['re_lu_37[0][0]']
#  a)
#
#  expanded_conv_14/squeeze_excit  (None, 4, 4, 960)   0           ['multiply_18[0][0]',
#  e/Mul (Multiply)                                                 'tf.math.multiply_26[0][0]']
#
#  expanded_conv_14/project (Conv  (None, 4, 4, 160)   153600      ['expanded_conv_14/squeeze_excite
#  2D)                                                             /Mul[0][0]']
#
#  expanded_conv_14/project/Batch  (None, 4, 4, 160)   640         ['expanded_conv_14/project[0][0]'
#  Norm (BatchNormalization)                                       ]
#
#  expanded_conv_14/Add (Add)     (None, 4, 4, 160)    0           ['expanded_conv_13/Add[0][0]',
#                                                                   'expanded_conv_14/project/BatchN
#                                                                  orm[0][0]']
#
#  Conv_1 (Conv2D)                (None, 4, 4, 960)    153600      ['expanded_conv_14/Add[0][0]']
#
#  Conv_1/BatchNorm (BatchNormali  (None, 4, 4, 960)   3840        ['Conv_1[0][0]']
#  zation)
#
#  tf.__operators__.add_27 (TFOpL  (None, 4, 4, 960)   0           ['Conv_1/BatchNorm[0][0]']
#  ambda)
#
#  re_lu_38 (ReLU)                (None, 4, 4, 960)    0           ['tf.__operators__.add_27[0][0]']
#
#  tf.math.multiply_27 (TFOpLambd  (None, 4, 4, 960)   0           ['re_lu_38[0][0]']
#  a)
#
#  multiply_19 (Multiply)         (None, 4, 4, 960)    0           ['Conv_1/BatchNorm[0][0]',
#                                                                   'tf.math.multiply_27[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 960)         0           ['multiply_19[0][0]']
#  2D)
#
#  dense (Dense)                  (None, 1)            961         ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 2,997,313
# Trainable params: 961
# Non-trainable params: 2,996,352
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping, ReduceLROnPlateau

patience = 3

start_lr = 0.00001
min_lr = 0.00001
max_lr = 0.00005

batch_size = 4

if TPU_INIT:
    max_lr = max_lr * tpu_strategy.num_replicas_in_sync
    batch_size = batch_size * tpu_strategy.num_replicas_in_sync

rampup_epochs = 5
sustain_epochs = 0
exp_decay = .8

def lrfn(epoch):
    if epoch < rampup_epochs:
        return (max_lr - start_lr)/rampup_epochs * epoch + start_lr
    elif epoch < rampup_epochs + sustain_epochs:
        return max_lr
    else:
        return (max_lr - min_lr) * exp_decay**(epoch-rampup_epochs-sustain_epochs) + min_lr


class myCallback(Callback):
    def on_epoch_end(self, epoch, logs={}):
        if ((logs.get('accuracy')>=0.999)):
            print("\nLimits Reached cancelling training!")
            self.model.stop_training = True

# %%
end_callback = myCallback()

lr_callback = LearningRateScheduler(lambda epoch: lrfn(epoch), verbose=False)

early_stopping = EarlyStopping(patience = patience, monitor='val_loss',
                                 mode='min', restore_best_weights=True, 
                                 verbose = 1, min_delta = .00075)

PROJECT_DIR = MyDrive + '/RiskDetection'

lr_plat = ReduceLROnPlateau(patience = 2, mode = 'min')

os.system('rm -rf ./logs/')

import datetime
log_dir="logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir = log_dir, write_graph=True, histogram_freq=1)

checkpoint_filepath = 'ModelWeights.h5'

model_checkpoints = ModelCheckpoint(filepath=checkpoint_filepath,
                                        save_weights_only=True,
                                        monitor='val_loss',
                                        mode='min',
                                        verbose = 1,
                                        save_best_only=True)


callbacks = [end_callback, lr_callback, model_checkpoints, tensorboard_callback, early_stopping, lr_plat]

if TPU_INIT:
    callbacks = [end_callback, lr_callback, model_checkpoints, early_stopping, lr_plat]

# %%
print('Training head...')
#model.load_weights('./Model_Weights_new.h5')

history = model.fit(X_train_nn ,y_train, epochs=epochs,
                        callbacks=callbacks,
                        validation_data = (X_test_nn, y_test),
                        batch_size=batch_size)

print('\nRestoring best Weights for MobileNetV3')
model.load_weights(checkpoint_filepath)
# Out:
# Training head...
# Epoch 1/60
#    1/2447 [..............................] - ETA: 3:25:11 - loss: 0.6636 - accuracy: 0.5000
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0076s vs `on_train_batch_end` time: 0.0158s). Check your callbacks.
# 2447/2447 [==============================] - ETA: 0s - loss: 0.6460 - accuracy: 0.6467
# Epoch 1: val_loss improved from inf to 0.56875, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 43s 15ms/step - loss: 0.6460 - accuracy: 0.6467 - val_loss: 0.5687 - val_accuracy: 0.6989 - lr: 1.0000e-05
# Epoch 2/60
# 2444/2447 [============================>.] - ETA: 0s - loss: 0.4733 - accuracy: 0.7800
# Epoch 2: val_loss improved from 0.56875 to 0.41556, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.4731 - accuracy: 0.7802 - val_loss: 0.4156 - val_accuracy: 0.8202 - lr: 1.8000e-05
# Epoch 3/60
# 2443/2447 [============================>.] - ETA: 0s - loss: 0.3545 - accuracy: 0.8582
# Epoch 3: val_loss improved from 0.41556 to 0.32679, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.3545 - accuracy: 0.8579 - val_loss: 0.3268 - val_accuracy: 0.8703 - lr: 2.6000e-05
# Epoch 4/60
# 2442/2447 [============================>.] - ETA: 0s - loss: 0.2849 - accuracy: 0.8895
# Epoch 4: val_loss improved from 0.32679 to 0.27850, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.2852 - accuracy: 0.8895 - val_loss: 0.2785 - val_accuracy: 0.8908 - lr: 3.4000e-05
# Epoch 5/60
# 2443/2447 [============================>.] - ETA: 0s - loss: 0.2427 - accuracy: 0.9058
# Epoch 5: val_loss improved from 0.27850 to 0.24330, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.2424 - accuracy: 0.9059 - val_loss: 0.2433 - val_accuracy: 0.9056 - lr: 4.2000e-05
# Epoch 6/60
# 2442/2447 [============================>.] - ETA: 0s - loss: 0.2138 - accuracy: 0.9175
# Epoch 6: val_loss improved from 0.24330 to 0.22054, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.2136 - accuracy: 0.9176 - val_loss: 0.2205 - val_accuracy: 0.9146 - lr: 5.0000e-05
# Epoch 7/60
# 2441/2447 [============================>.] - ETA: 0s - loss: 0.1939 - accuracy: 0.9260
# Epoch 7: val_loss improved from 0.22054 to 0.20798, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.1938 - accuracy: 0.9261 - val_loss: 0.2080 - val_accuracy: 0.9216 - lr: 4.2000e-05
# Epoch 8/60
# 2444/2447 [============================>.] - ETA: 0s - loss: 0.1819 - accuracy: 0.9309
# Epoch 8: val_loss improved from 0.20798 to 0.20018, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1819 - accuracy: 0.9308 - val_loss: 0.2002 - val_accuracy: 0.9249 - lr: 3.5600e-05
# Epoch 9/60
# 2445/2447 [============================>.] - ETA: 0s - loss: 0.1734 - accuracy: 0.9343
# Epoch 9: val_loss improved from 0.20018 to 0.19436, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.1735 - accuracy: 0.9342 - val_loss: 0.1944 - val_accuracy: 0.9256 - lr: 3.0480e-05
# Epoch 10/60
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1677 - accuracy: 0.9358
# Epoch 10: val_loss improved from 0.19436 to 0.18992, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1677 - accuracy: 0.9358 - val_loss: 0.1899 - val_accuracy: 0.9278 - lr: 2.6384e-05
# Epoch 11/60
# 2444/2447 [============================>.] - ETA: 0s - loss: 0.1629 - accuracy: 0.9380
# Epoch 11: val_loss improved from 0.18992 to 0.18647, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.1629 - accuracy: 0.9381 - val_loss: 0.1865 - val_accuracy: 0.9287 - lr: 2.3107e-05
# Epoch 12/60
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1591 - accuracy: 0.9396
# Epoch 12: val_loss improved from 0.18647 to 0.18408, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.1591 - accuracy: 0.9396 - val_loss: 0.1841 - val_accuracy: 0.9294 - lr: 2.0486e-05
# Epoch 13/60
# 2442/2447 [============================>.] - ETA: 0s - loss: 0.1560 - accuracy: 0.9431
# Epoch 13: val_loss improved from 0.18408 to 0.18173, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.1560 - accuracy: 0.9432 - val_loss: 0.1817 - val_accuracy: 0.9299 - lr: 1.8389e-05
# Epoch 14/60
# 2443/2447 [============================>.] - ETA: 0s - loss: 0.1535 - accuracy: 0.9428
# Epoch 14: val_loss improved from 0.18173 to 0.18031, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1533 - accuracy: 0.9429 - val_loss: 0.1803 - val_accuracy: 0.9311 - lr: 1.6711e-05
# Epoch 15/60
# 2442/2447 [============================>.] - ETA: 0s - loss: 0.1508 - accuracy: 0.9455
# Epoch 15: val_loss improved from 0.18031 to 0.17829, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.1509 - accuracy: 0.9454 - val_loss: 0.1783 - val_accuracy: 0.9316 - lr: 1.5369e-05
# Epoch 16/60
# 2445/2447 [============================>.] - ETA: 0s - loss: 0.1490 - accuracy: 0.9449
# Epoch 16: val_loss improved from 0.17829 to 0.17671, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.1490 - accuracy: 0.9448 - val_loss: 0.1767 - val_accuracy: 0.9325 - lr: 1.4295e-05
# Epoch 17/60
# 2443/2447 [============================>.] - ETA: 0s - loss: 0.1473 - accuracy: 0.9468
# Epoch 17: val_loss improved from 0.17671 to 0.17534, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.1474 - accuracy: 0.9468 - val_loss: 0.1753 - val_accuracy: 0.9344 - lr: 1.3436e-05
# Epoch 18/60
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1457 - accuracy: 0.9473
# Epoch 18: val_loss improved from 0.17534 to 0.17409, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 33s 13ms/step - loss: 0.1457 - accuracy: 0.9473 - val_loss: 0.1741 - val_accuracy: 0.9349 - lr: 1.2749e-05
# Epoch 19/60
# 2445/2447 [============================>.] - ETA: 0s - loss: 0.1443 - accuracy: 0.9479
# Epoch 19: val_loss improved from 0.17409 to 0.17298, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1442 - accuracy: 0.9479 - val_loss: 0.1730 - val_accuracy: 0.9349 - lr: 1.2199e-05
# Epoch 20/60
# 2445/2447 [============================>.] - ETA: 0s - loss: 0.1430 - accuracy: 0.9482
# Epoch 20: val_loss improved from 0.17298 to 0.17213, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1430 - accuracy: 0.9482 - val_loss: 0.1721 - val_accuracy: 0.9335 - lr: 1.1759e-05
# Epoch 21/60
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1416 - accuracy: 0.9491
# Epoch 21: val_loss improved from 0.17213 to 0.17113, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1417 - accuracy: 0.9490 - val_loss: 0.1711 - val_accuracy: 0.9342 - lr: 1.1407e-05
# Epoch 22/60
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1404 - accuracy: 0.9493
# Epoch 22: val_loss improved from 0.17113 to 0.17072, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.1405 - accuracy: 0.9493 - val_loss: 0.1707 - val_accuracy: 0.9349 - lr: 1.1126e-05
# Epoch 23/60
# 2441/2447 [============================>.] - ETA: 0s - loss: 0.1393 - accuracy: 0.9507
# Epoch 23: val_loss improved from 0.17072 to 0.16940, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1394 - accuracy: 0.9505 - val_loss: 0.1694 - val_accuracy: 0.9351 - lr: 1.0901e-05
# Epoch 24/60
# 2445/2447 [============================>.] - ETA: 0s - loss: 0.1384 - accuracy: 0.9506
# Epoch 24: val_loss improved from 0.16940 to 0.16876, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.1384 - accuracy: 0.9506 - val_loss: 0.1688 - val_accuracy: 0.9349 - lr: 1.0721e-05
# Epoch 25/60
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1373 - accuracy: 0.9505
# Epoch 25: val_loss improved from 0.16876 to 0.16818, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1373 - accuracy: 0.9505 - val_loss: 0.1682 - val_accuracy: 0.9347 - lr: 1.0576e-05
# Epoch 26/60
# 2444/2447 [============================>.] - ETA: 0s - loss: 0.1364 - accuracy: 0.9518
# Epoch 26: val_loss improved from 0.16818 to 0.16742, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.1363 - accuracy: 0.9519 - val_loss: 0.1674 - val_accuracy: 0.9349 - lr: 1.0461e-05
# Epoch 27/60
# 2444/2447 [============================>.] - ETA: 0s - loss: 0.1355 - accuracy: 0.9517
# Epoch 27: val_loss improved from 0.16742 to 0.16654, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1355 - accuracy: 0.9518 - val_loss: 0.1665 - val_accuracy: 0.9359 - lr: 1.0369e-05
# Epoch 28/60
# 2443/2447 [============================>.] - ETA: 0s - loss: 0.1344 - accuracy: 0.9526
# Epoch 28: val_loss improved from 0.16654 to 0.16571, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.1345 - accuracy: 0.9525 - val_loss: 0.1657 - val_accuracy: 0.9387 - lr: 1.0295e-05
# Epoch 29/60
# 2445/2447 [============================>.] - ETA: 0s - loss: 0.1337 - accuracy: 0.9537
# Epoch 29: val_loss improved from 0.16571 to 0.16542, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.1336 - accuracy: 0.9537 - val_loss: 0.1654 - val_accuracy: 0.9368 - lr: 1.0236e-05
# Epoch 30/60
# 2444/2447 [============================>.] - ETA: 0s - loss: 0.1328 - accuracy: 0.9527
# Epoch 30: val_loss improved from 0.16542 to 0.16459, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 31s 13ms/step - loss: 0.1328 - accuracy: 0.9527 - val_loss: 0.1646 - val_accuracy: 0.9368 - lr: 1.0189e-05
# Epoch 31/60
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1320 - accuracy: 0.9538
# Epoch 31: val_loss improved from 0.16459 to 0.16380, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.1320 - accuracy: 0.9538 - val_loss: 0.1638 - val_accuracy: 0.9392 - lr: 1.0151e-05
# Epoch 32/60
# 2444/2447 [============================>.] - ETA: 0s - loss: 0.1311 - accuracy: 0.9545
# Epoch 32: val_loss improved from 0.16380 to 0.16319, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1311 - accuracy: 0.9545 - val_loss: 0.1632 - val_accuracy: 0.9380 - lr: 1.0121e-05
# Epoch 33/60
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1303 - accuracy: 0.9549
# Epoch 33: val_loss improved from 0.16319 to 0.16279, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1303 - accuracy: 0.9549 - val_loss: 0.1628 - val_accuracy: 0.9380 - lr: 1.0097e-05
# Epoch 34/60
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1295 - accuracy: 0.9551
# Epoch 34: val_loss improved from 0.16279 to 0.16217, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 31s 13ms/step - loss: 0.1295 - accuracy: 0.9551 - val_loss: 0.1622 - val_accuracy: 0.9390 - lr: 1.0077e-05
# Epoch 35/60
# 2444/2447 [============================>.] - ETA: 0s - loss: 0.1288 - accuracy: 0.9554
# Epoch 35: val_loss improved from 0.16217 to 0.16146, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 31s 13ms/step - loss: 0.1287 - accuracy: 0.9554 - val_loss: 0.1615 - val_accuracy: 0.9392 - lr: 1.0062e-05
# Epoch 36/60
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1281 - accuracy: 0.9554
# Epoch 36: val_loss improved from 0.16146 to 0.16095, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1281 - accuracy: 0.9554 - val_loss: 0.1610 - val_accuracy: 0.9390 - lr: 1.0050e-05
# Epoch 37/60
# 2446/2447 [============================>.] - ETA: 0s - loss: 0.1273 - accuracy: 0.9556
# Epoch 37: val_loss improved from 0.16095 to 0.16038, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1273 - accuracy: 0.9556 - val_loss: 0.1604 - val_accuracy: 0.9399 - lr: 1.0040e-05
# Epoch 38/60
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1266 - accuracy: 0.9565
# Epoch 38: val_loss improved from 0.16038 to 0.15992, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 31s 13ms/step - loss: 0.1266 - accuracy: 0.9565 - val_loss: 0.1599 - val_accuracy: 0.9404 - lr: 1.0032e-05
# Epoch 39/60
# 2442/2447 [============================>.] - ETA: 0s - loss: 0.1258 - accuracy: 0.9561
# Epoch 39: val_loss improved from 0.15992 to 0.15954, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1259 - accuracy: 0.9560 - val_loss: 0.1595 - val_accuracy: 0.9399 - lr: 1.0025e-05
# Epoch 40/60
# 2445/2447 [============================>.] - ETA: 0s - loss: 0.1253 - accuracy: 0.9574
# Epoch 40: val_loss improved from 0.15954 to 0.15901, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 31s 13ms/step - loss: 0.1253 - accuracy: 0.9574 - val_loss: 0.1590 - val_accuracy: 0.9402 - lr: 1.0020e-05
# Epoch 41/60
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1245 - accuracy: 0.9573
# Epoch 41: val_loss improved from 0.15901 to 0.15835, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.1245 - accuracy: 0.9573 - val_loss: 0.1583 - val_accuracy: 0.9411 - lr: 1.0016e-05
# Epoch 42/60
# 2444/2447 [============================>.] - ETA: 0s - loss: 0.1240 - accuracy: 0.9570
# Epoch 42: val_loss improved from 0.15835 to 0.15794, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1239 - accuracy: 0.9571 - val_loss: 0.1579 - val_accuracy: 0.9402 - lr: 1.0013e-05
# Epoch 43/60
# 2443/2447 [============================>.] - ETA: 0s - loss: 0.1231 - accuracy: 0.9587
# Epoch 43: val_loss did not improve from 0.15794
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1230 - accuracy: 0.9587 - val_loss: 0.1586 - val_accuracy: 0.9397 - lr: 1.0010e-05
# Epoch 44/60
# 2442/2447 [============================>.] - ETA: 0s - loss: 0.1228 - accuracy: 0.9576
# Epoch 44: val_loss improved from 0.15794 to 0.15703, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1227 - accuracy: 0.9576 - val_loss: 0.1570 - val_accuracy: 0.9411 - lr: 1.0008e-05
# Epoch 45/60
# 2445/2447 [============================>.] - ETA: 0s - loss: 0.1221 - accuracy: 0.9576
# Epoch 45: val_loss improved from 0.15703 to 0.15647, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.1220 - accuracy: 0.9576 - val_loss: 0.1565 - val_accuracy: 0.9416 - lr: 1.0007e-05
# Epoch 46/60
# 2444/2447 [============================>.] - ETA: 0s - loss: 0.1214 - accuracy: 0.9587
# Epoch 46: val_loss improved from 0.15647 to 0.15604, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1214 - accuracy: 0.9587 - val_loss: 0.1560 - val_accuracy: 0.9418 - lr: 1.0005e-05
# Epoch 47/60
# 2441/2447 [============================>.] - ETA: 0s - loss: 0.1210 - accuracy: 0.9589
# Epoch 47: val_loss improved from 0.15604 to 0.15561, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1208 - accuracy: 0.9590 - val_loss: 0.1556 - val_accuracy: 0.9413 - lr: 1.0004e-05
# Epoch 48/60
# 2444/2447 [============================>.] - ETA: 0s - loss: 0.1202 - accuracy: 0.9586
# Epoch 48: val_loss improved from 0.15561 to 0.15522, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.1201 - accuracy: 0.9586 - val_loss: 0.1552 - val_accuracy: 0.9416 - lr: 1.0003e-05
# Epoch 49/60
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1197 - accuracy: 0.9595
# Epoch 49: val_loss improved from 0.15522 to 0.15521, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1197 - accuracy: 0.9595 - val_loss: 0.1552 - val_accuracy: 0.9418 - lr: 1.0003e-05
# Epoch 50/60
# 2441/2447 [============================>.] - ETA: 0s - loss: 0.1192 - accuracy: 0.9594
# Epoch 50: val_loss improved from 0.15521 to 0.15444, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.1191 - accuracy: 0.9595 - val_loss: 0.1544 - val_accuracy: 0.9423 - lr: 1.0002e-05
# Epoch 51/60
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1184 - accuracy: 0.9594
# Epoch 51: val_loss improved from 0.15444 to 0.15428, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1184 - accuracy: 0.9594 - val_loss: 0.1543 - val_accuracy: 0.9428 - lr: 1.0002e-05
# Epoch 52/60
# 2444/2447 [============================>.] - ETA: 0s - loss: 0.1179 - accuracy: 0.9595
# Epoch 52: val_loss improved from 0.15428 to 0.15364, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1179 - accuracy: 0.9595 - val_loss: 0.1536 - val_accuracy: 0.9428 - lr: 1.0001e-05
# Epoch 53/60
# 2441/2447 [============================>.] - ETA: 0s - loss: 0.1173 - accuracy: 0.9601
# Epoch 53: val_loss improved from 0.15364 to 0.15333, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1175 - accuracy: 0.9600 - val_loss: 0.1533 - val_accuracy: 0.9433 - lr: 1.0001e-05
# Epoch 54/60
# 2443/2447 [============================>.] - ETA: 0s - loss: 0.1169 - accuracy: 0.9606
# Epoch 54: val_loss improved from 0.15333 to 0.15300, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1169 - accuracy: 0.9607 - val_loss: 0.1530 - val_accuracy: 0.9430 - lr: 1.0001e-05
# Epoch 55/60
# 2441/2447 [============================>.] - ETA: 0s - loss: 0.1164 - accuracy: 0.9610
# Epoch 55: val_loss improved from 0.15300 to 0.15267, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1164 - accuracy: 0.9610 - val_loss: 0.1527 - val_accuracy: 0.9430 - lr: 1.0001e-05
# Epoch 56/60
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1159 - accuracy: 0.9610
# Epoch 56: val_loss improved from 0.15267 to 0.15220, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.1159 - accuracy: 0.9610 - val_loss: 0.1522 - val_accuracy: 0.9435 - lr: 1.0001e-05
# Epoch 57/60
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1154 - accuracy: 0.9613
# Epoch 57: val_loss improved from 0.15220 to 0.15201, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.1154 - accuracy: 0.9613 - val_loss: 0.1520 - val_accuracy: 0.9437 - lr: 1.0000e-05
# Epoch 58/60
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1148 - accuracy: 0.9604
# Epoch 58: val_loss improved from 0.15201 to 0.15159, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1148 - accuracy: 0.9604 - val_loss: 0.1516 - val_accuracy: 0.9437 - lr: 1.0000e-05
# Epoch 59/60
# 2443/2447 [============================>.] - ETA: 0s - loss: 0.1145 - accuracy: 0.9624
# Epoch 59: val_loss improved from 0.15159 to 0.15120, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 29s 12ms/step - loss: 0.1144 - accuracy: 0.9625 - val_loss: 0.1512 - val_accuracy: 0.9437 - lr: 1.0000e-05
# Epoch 60/60
# 2447/2447 [==============================] - ETA: 0s - loss: 0.1138 - accuracy: 0.9622
# Epoch 60: val_loss improved from 0.15120 to 0.15113, saving model to ModelWeights.h5
# 2447/2447 [==============================] - 30s 12ms/step - loss: 0.1138 - accuracy: 0.9622 - val_loss: 0.1511 - val_accuracy: 0.9442 - lr: 1.0000e-05
#
# Restoring best Weights for MobileNetV3

# %%
# %matplotlib inline

def print_graph(item, index, history):
    plt.figure()
    train_values = history.history[item][0:index]
    plt.plot(train_values)
    test_values = history.history['val_' + item][0:index]
    plt.plot(test_values)
    plt.legend(['training','validation'])
    plt.title('Training and validation '+ item)
    plt.xlabel('epoch')
    plt.show()
    plot = '{}.png'.format(item)
    plt.savefig(plot)


def get_best_epoch(test_loss, history):
    for key, item in enumerate(history.history.items()):
        (name, arr) = item
        if name == 'val_loss':
            for i in range(len(arr)):
                if round(test_loss, 2) == round(arr[i], 2):
                    return i
                
def model_summary(model, history):
    print('---'*30)
    test_loss, test_accuracy = model.evaluate(X_test_nn, y_test, verbose=0)

    if history:
        index = get_best_epoch(test_loss, history)
        print('Best Epochs: ', index)

        train_accuracy = history.history['accuracy'][index]
        train_loss = history.history['loss'][index]

        print('Accuracy on train:',train_accuracy,'\tLoss on train:',train_loss)
        print('Accuracy on test:',test_accuracy,'\tLoss on test:',test_loss)
        print_graph('loss', index, history)
        print_graph('accuracy', index, history)
        print('---'*30)

# %%
model_summary(model, history)
# Out:
# ------------------------------------------------------------------------------------------
# Best Epochs:  31
# Accuracy on train: 0.9616789817810059 	Loss on train: 0.11210563778877258
# Accuracy on test: 0.9577874541282654 	Loss on test: 0.116333968937397
# ------------------------------------------------------------------------------------------

# %% [markdown]
# ## **Evaluation on test set**

# %%
# evaluate the network
print("Evaluating network...")
predictions = model.predict(X_test_nn)
preds = predictions > 0.5
# Out:
# Evaluating network...

# %%
import seaborn as sns
from sklearn import metrics
from sklearn.metrics import roc_curve, roc_auc_score, plot_roc_curve, accuracy_score, classification_report, confusion_matrix
corr_pred = metrics.confusion_matrix(y_test, preds)

n_correct = np.int((corr_pred[0][0] + corr_pred[1][1]))
print('> Correct Predictions:', n_correct)
n_wrongs = np.int((corr_pred[0][1] + (corr_pred[1][0])))
print('> Wrong Predictions:', n_wrongs)

sns.heatmap(corr_pred,annot=True, fmt="d",cmap="Blues")
plt.show()

print(metrics.classification_report(y_test, preds, 
                           target_names=["NonViolence", "Violence"]))
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_6244/3180812836.py:6: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   n_correct = np.int((corr_pred[0][0] + corr_pred[1][1]))
# C:\Users\hp\AppData\Local\Temp/ipykernel_6244/3180812836.py:8: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   n_wrongs = np.int((corr_pred[0][1] + (corr_pred[1][0])))
# > Correct Predictions: 4606
# > Wrong Predictions: 203
#               precision    recall  f1-score   support
#
#  NonViolence       0.96      0.95      0.95      2243
#     Violence       0.96      0.96      0.96      2566
#
#     accuracy                           0.96      4809
#    macro avg       0.96      0.96      0.96      4809
# weighted avg       0.96      0.96      0.96      4809

# %%
args_model = "/content/drive/MyDrive/Front end/modelnew.h5"
model.save(args_model)
