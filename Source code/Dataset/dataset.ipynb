# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/MyDrive/dataset"

# %%
# %cd /content/drive/MyDrive/dataset
# Out:
# /content/drive/MyDrive/dataset

# %%
# !kaggle datasets download -d mohamedmustafa/real-life-violence-situations-dataset --unzip
# Out:
# Downloading real-life-violence-situations-dataset.zip to /content/drive/MyDrive/dataset
# 100% 3.58G/3.58G [00:40<00:00, 114MB/s]
# 100% 3.58G/3.58G [00:40<00:00, 94.9MB/s]
